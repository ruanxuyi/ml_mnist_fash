# %% [markdown]
# ## 2. Gaussian Naive Bayes + MLE
#
# ### Experiment results
#
# | Classifier Type  | Test Accur.  | Train time | Config.  |
# | :------------- |:-------------:| -------------:| :---------|
# | GaussianNB (NO PCA)   | 55.58% | 2.87 seconds| NA              |
# | GaussianNB             | 72.09%    |   0.28 seconds | $pca=400$      |
#
#
#
# GaussianNB Cross validation chart:
#
# ```
# ubuntu@ip-172-31-16-222:~/tf/633/ml_mnist_fash/p2$ python MNIST_fash_bayes.py
# Extracting ../MNIST_data/fashion/train-images-idx3-ubyte.gz
# Extracting ../MNIST_data/fashion/train-labels-idx1-ubyte.gz
# Extracting ../MNIST_data/fashion/t10k-images-idx3-ubyte.gz
# Extracting ../MNIST_data/fashion/t10k-labels-idx1-ubyte.gz
# PCA processing...
# PCA done...
# n_component: 50
# Accuracy: 0.6861.
# Time to classify: 0.21 seconds.
# PCA processing...
# PCA done...
# n_component: 100
# Accuracy: 0.7038.
# Time to classify: 0.39 seconds.
# PCA processing...
# PCA done...
# n_component: 150
# Accuracy: 0.7123.
# Time to classify: 0.54 seconds.
# PCA processing...
# PCA done...
# n_component: 200
# Accuracy: 0.7150.
# Time to classify: 0.73 seconds.
# PCA processing...
# PCA done...
# n_component: 250
# Accuracy: 0.7188.
# Time to classify: 0.91 seconds.
# PCA processing...
# PCA done...
# n_component: 300
# Accuracy: 0.7174.
# Time to classify: 1.09 seconds.
# PCA processing...
# PCA done...
# n_component: 350
# Accuracy: 0.7207.
# Time to classify: 1.18 seconds.
# PCA processing...
# PCA done...
# n_component: 400
# Accuracy: 0.7209.
# Time to classify: 1.42 seconds.
# PCA processing...
# PCA done...
# n_component: 450
# Accuracy: 0.7203.
# Time to classify: 1.61 seconds.
# ```
#
# ## 3. Nearest Neighbor Rule
# -  non-parametric technique
#
# ### Experiment results
#
#
#
#
#
#
# # References:
#
# ## Naive Bayes
#
# http://scikit-learn.org/stable/modules/naive_bayes.html#gaussian-naive-bayes
#
# ## KNN
# http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html#sklearn.neighbors.KNeighborsClassifier
#
# https://steven.codes/blog/ml/how-to-get-97-percent-on-MNIST-with-KNN/
#
# ## PCA
#
# fit() and transform() methods:
# https://stackoverflow.com/questions/23838056/what-is-the-difference-between-transform-and-fit-transform-in-sklearn
#
# PCA returned negative values
# https://stackoverflow.com/questions/34725726/is-it-possible-apply-pca-on-any-text-classification
#
#
# ## Questions:
# https://lazyprogrammer.me/bayes-classifier-and-naive-bayes-tutorial-using/
# 1. probabilities are very small when dimensionality is high ??
#
#
# Good tutorial on Bayes basic:
# https://lazyprogrammer.me/bayes-classifier-and-naive-bayes-tutorial-using/
#
# Naive Bayes on MNIST dataset
# https://github.com/bikz05/ipython-notebooks/blob/master/machine-learning/naive-bayes-mnist-sklearn.ipynb
#
# Code:
# 1. https://github.com/haidawyl/Mnist/blob/master/bayes.py
# 2. 81.7% MultinomialNB(): https://github.com/bikz05/ipython-notebooks/blob/master/machine-learning/naive-bayes-mnist-sklearn.ipynb
#
# brown hw:
# http://cs.brown.edu/courses/csci1950-f/fall2009/docs/wk04.pdf
