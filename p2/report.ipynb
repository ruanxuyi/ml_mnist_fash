# %% [markdown]
# ## 2. Gaussian Naive Bayes + MLE
#
# ### Experiment results
#
# | Classifier Type  | Test Accur.  | Train time | Config.  |
# | :------------- |:-------------:| -------------:| :---------|
# | GaussianNB (NO PCA)   | 55.58% | 2.87 seconds| NA              |
# | GaussianNB             | 88.22%    |   0.28 seconds | $pca=80$      |
#
#
#
# GaussianNB Cross validation chart:
#
# ```
# PCA processing...
# PCA done...
# n_component: 10
# Accuracy: 0.7784.
# Time to classify: 0.07 seconds.
# PCA processing...
# PCA done...
# n_component: 20
# Accuracy: 0.8537.
# Time to classify: 0.10 seconds.
# PCA processing...
# PCA done...
# n_component: 30
# Accuracy: 0.8685.
# Time to classify: 0.13 seconds.
# PCA processing...
# PCA done...
# n_component: 40
# Accuracy: 0.8743.
# Time to classify: 0.16 seconds.
# PCA processing...
# PCA done...
# n_component: 50
# Accuracy: 0.8781.
# Time to classify: 0.19 seconds.
# PCA processing...
# PCA done...
# n_component: 60
# Accuracy: 0.8804.
# Time to classify: 0.22 seconds.
# PCA processing...
# PCA done...
# n_component: 70
# Accuracy: 0.8811.
# Time to classify: 0.24 seconds.
# PCA processing...
# PCA done...
# n_component: 80
# Accuracy: 0.8822.
# Time to classify: 0.28 seconds.
# PCA processing...
# PCA done...
# n_component: 90
# Accuracy: 0.8817.
# Time to classify: 0.31 seconds.
# PCA processing...
# PCA done...
# n_component: 100
# Accuracy: 0.8771.
# Time to classify: 0.34 seconds.
# PCA processing...
# PCA done...
# n_component: 110
# from svmutil import *
# Accuracy: 0.8745.
# Time to classify: 0.37 seconds.
# PCA processing...
# PCA done...
# n_component: 120
# Accuracy: 0.8741.
# Time to classify: 0.39 seconds.
# PCA processing...
# PCA done...
# n_component: 130
# Accuracy: 0.8720.
# Time to classify: 0.43 seconds.
# PCA processing...
# PCA done...
# n_component: 140
# Accuracy: 0.8717.
# Time to classify: 0.47 seconds.
# PCA processing...
# PCA done...
# n_component: 150
# Accuracy: 0.8659.
# Time to classify: 0.49 seconds.
# PCA processing...
#
# PCA done...
# n_component: 160
# Accuracy: 0.8671.
# Time to classify: 0.52 seconds.
# PCA processing...
# PCA done...
# n_component: 170
# Accuracy: 0.8616.
# Time to classify: 0.57 seconds.
# PCA processing...
# PCA done...
# n_component: 180
#
# Accuracy: 0.8592.
# Time to classify: 0.60 seconds.
# PCA processing...
# PCA done...
# n_component: 190
# Accuracy: 0.8574.
# Time to classify: 0.62 seconds.
# ```
#
# ## 3. Nearest Neighbor Rule
# -  non-parametric technique
#
# ### Experiment results
#
# | Classifier Type   | Test Accur.  | Train time | Config.  |
# | :------------- |:-------------:| -------------:| -----:|
# | LeNet/CNN	 | 91.54%     |    104.87 mins| detail below |
# | ResNet Like | 93.81%     |     2:50:26s | detail below |
# | VGG Like | 91.67%*     |    1:22:23s* | detail below |
#
#
# ## Naive Bayes
#
# http://scikit-learn.org/stable/modules/naive_bayes.html#gaussian-naive-bayes
#
# ## PCA
#
# fit() and transform() methods:
# https://stackoverflow.com/questions/23838056/what-is-the-difference-between-transform-and-fit-transform-in-sklearn
#
# PCA returned negative values
# https://stackoverflow.com/questions/34725726/is-it-possible-apply-pca-on-any-text-classification
#
#
# ## Questions:
# https://lazyprogrammer.me/bayes-classifier-and-naive-bayes-tutorial-using/
# 1. probabilities are very small when dimensionality is high ??
#
#
# Good tutorial on Bayes basic:
# https://lazyprogrammer.me/bayes-classifier-and-naive-bayes-tutorial-using/
#
# Naive Bayes on MNIST dataset
# https://github.com/bikz05/ipython-notebooks/blob/master/machine-learning/naive-bayes-mnist-sklearn.ipynb
#
# Code:
# 1. https://github.com/haidawyl/Mnist/blob/master/bayes.py
# 2. 81.7% MultinomialNB(): https://github.com/bikz05/ipython-notebooks/blob/master/machine-learning/naive-bayes-mnist-sklearn.ipynb
#
# brown hw:
# http://cs.brown.edu/courses/csci1950-f/fall2009/docs/wk04.pdf
